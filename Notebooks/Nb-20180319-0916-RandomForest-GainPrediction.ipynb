# %% [markdown]
# # Nb-20180319-0916-RandomForest-GainPrediction

# %%
STAMP = "20180319-0916"

# %% [markdown]
# This is a modification of the previous notebook.
#
# **Fixed error in calculating the value of the dependent variable, 'Gain 1d'. **
#
# Do a simple random forest to try to predict if a stock ticker will make a gain the next day.

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from collections import defaultdict
import operator

# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.colors as colors
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics

# %%
import finance as fat

# %%
# Change the plot size.
plt.rcParams['figure.figsize'] = [18.0, 10.0]

# %%
tickers = ['AAPL', 'FB', 'IBM', 'GOOG', 'MSFT']

# %%
def create_ml_ticker_features_df(ticker) :
    data = fat.get_price_data(ticker)
    
    # check for required columns in data
    for c in ['Open','High','Low','Close','Adj Close', 'Volume'] :
        assert c in data.columns, f'{ticker} does not contain data for {c}'
    
    # Price features
    data = adjust_ohlc_prices(data)
    data = add_history(data, 'Adj Close', range(-5, 0))
    data = fat.add_sma_columns(data, 'Adj Close', [6,12,20,200])
    data = fat.add_ema_columns(data, 'Adj Close', [3,6,12,26,50])
    data = fat.add_bollinger_bands(data, 'Adj Close')
    data = scale_columns(data, 1.0/data['Adj Close'], column_contains='Adj')
    # 'Adj Close' data has all been scaled to 1.0, so get rid of it
    del data['Adj Close']
    # data = add_ohlc_booleans(data)
    
    # Volume features
    # ... first, replace 0's with 1's so we don't divide by zero when scaling (some data has 0's in volume)
    data['Volume'] = data['Volume'].replace(0, 1)
    data = add_history(data, 'Volume', range(-5, 0))
    data = scale_columns(data, 1.0/data['Volume'], column_contains='Volume')
    # 'Volume' data has all been scaled to 1.0, so get rid of it
    del data['Volume']
    
    return data

# %%
def adjust_ohlc_prices(data_frame, inplace=False) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    
    df = fat.use_data_frame_if_inplace(data_frame, inplace)
    
    columns = ['Open', 'High', 'Low', 'Close']
    scaling = df['Close'] / df['Adj Close']
    for c in columns :
        df[c] /= scaling
    
    del df['Adj Close']
    
    # rename columns, add 'Adj ' to name
    new_cols = {c : ('Adj '+c) for c in columns}
    df.rename(columns=new_cols, inplace=True)
    return df

# %%
def add_history(data_frame, column, day_range, inplace=False) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    df = fat.use_data_frame_if_inplace(data_frame, inplace)
    
    for i in day_range :
        df[f'{column} {i}d'] = df[column].shift(-i)
    return df

# %%
def scale_columns(data_frame, scaling, column_contains, inplace=False) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    df = fat.use_data_frame_if_inplace(data_frame, inplace)
    
    for c in df.columns : 
        if column_contains in c :
            df[c] *= scaling
    return df

# %%
def add_ticker(data_frame, ticker) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    df = data_frame.copy()
    
    df['Ticker'] = ticker
    
    # ... and rearrange columns to put ticker in front 
    cols = df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    df = df[cols]
    
    return df

# %%
data_raw = None
for t in tickers :
    df = create_ml_ticker_features_df(t)
    df = fat.create_ml_features_df(df)
    df = add_ticker(df, t)
    
    df['Gain +1d'] = df['Adj Close -1d'].shift(-1) < 1.0
    
    data_raw = df.append(data_raw)
# Out:
# Could not load updates for AAPL from yahoo. Using cached data.
# Loaded data for AAPL: 1980-12-12 to 2018-03-16.
# Could not load updates for FB from yahoo. Using cached data.
# Loaded data for FB: 2012-05-18 to 2018-03-16.
# Could not load updates for IBM from yahoo. Using cached data.
# Loaded data for IBM: 1970-01-02 to 2018-03-16.
# Could not load updates for GOOG from yahoo. Using cached data.
# Loaded data for GOOG: 2004-08-19 to 2018-03-16.
# Could not load updates for MSFT from yahoo. Using cached data.
# Loaded data for MSFT: 1986-03-13 to 2018-03-16.

# %%
data_raw.tail()
# Out:
#            Ticker  Adj Open  Adj High   Adj Low  Adj Close -5d  Adj Close -4d  \
# Date
# 2018-03-12   AAPL  0.992131  1.003687  0.991691       0.973035       0.972210
# 2018-03-13   AAPL  1.014558  1.019614  0.995944       0.981664       0.972551
# 2018-03-14   AAPL  1.010536  1.011657  0.996469       0.980890       0.991594
# 2018-03-15   AAPL  0.999160  1.008900  0.996754       0.990428       1.007445
# 2018-03-16   AAPL  1.003539  1.006179  0.997753       1.011010       1.020784
#
#             Adj Close -3d  Adj Close -2d  Adj Close -1d  Adj Close SMA6  \
# Date
# 2018-03-12       0.963185       0.973696       0.990425        0.978759
# 2018-03-13       0.983164       1.000056       1.009724        0.991193
# 2018-03-14       1.008630       1.018382       1.008574        1.001345
# 2018-03-15       1.017184       1.007389       0.998825        1.003545
# 2018-03-16       1.010954       1.002359       1.003539        1.008108
#
#               ...     Dayofweek  Dayofyear  Is_month_end  Is_month_start  \
# Date          ...
# 2018-03-12    ...             0         71         False           False
# 2018-03-13    ...             1         72         False           False
# 2018-03-14    ...             2         73         False           False
# 2018-03-15    ...             3         74         False           False
# 2018-03-16    ...             4         75         False           False
#
#             Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start  \
# Date
# 2018-03-12           False             False        False          False
# 2018-03-13           False             False        False          False
# 2018-03-14           False             False        False          False
# 2018-03-15           False             False        False          False
# 2018-03-16           False             False        False          False
#
#                Elapsed  Gain +1d
# Date
# 2018-03-12  1520812800     False
# 2018-03-13  1520899200     False
# 2018-03-14  1520985600      True
# 2018-03-15  1521072000     False
# 2018-03-16  1521158400     False
#
# [5 rows x 41 columns]

# %%
data_raw = data_raw.sort_index()
data_raw.describe().T
# Out:
#                        count          mean           std           min  \
# Adj Open             34511.0  1.000351e+00  3.750595e-02  8.384615e-01
# Adj High             34511.0  1.012602e+00  3.558246e-02  1.000000e+00
# Adj Low              34511.0  9.877507e-01  1.306389e-02  7.788786e-01
# Adj Close -5d        34486.0  9.975326e-01  5.094059e-02  5.995718e-01
# Adj Close -4d        34491.0  9.980339e-01  4.559276e-02  6.573880e-01
# Adj Close -3d        34496.0  9.985408e-01  3.981539e-02  6.766591e-01
# Adj Close -2d        34501.0  9.990359e-01  3.258341e-02  6.766591e-01
# Adj Close -1d        34506.0  9.995164e-01  2.292707e-02  7.505934e-01
# Adj Close SMA6       34486.0  9.987715e-01  2.819414e-02  7.519628e-01
# Adj Close SMA12      34456.0  9.972816e-01  4.297491e-02  6.572091e-01
# Adj Close SMA20      34416.0  9.953177e-01  5.781247e-02  6.183081e-01
# Adj Close SMA200     33516.0  9.525864e-01  1.878917e-01  4.509626e-01
# Volume -5d           7.345881e-01  1.013557e+00  1.379130e+00  1.590400e+06
# Volume -4d           7.421114e-01  1.015388e+00  1.367068e+00  2.911200e+06
# Volume -3d           7.487887e-01  1.014512e+00  1.358313e+00  3.924800e+06
# Volume -2d           7.636667e-01  1.017422e+00  1.335642e+00  2.710000e+06
# Volume -1d           7.971486e-01  1.015729e+00  1.275722e+00  3.030400e+06
# Days Since Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Days Until Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Year                 1.990000e+03  2.001000e+03  2.011000e+03  2.018000e+03
# Month                4.000000e+00  7.000000e+00  1.000000e+01  1.200000e+01
# Week                 1.400000e+01  2.700000e+01  4.000000e+01  5.300000e+01
# Day                  8.000000e+00  1.600000e+01  2.300000e+01  3.100000e+01
# Dayofweek            1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
# Dayofyear            9.200000e+01  1.830000e+02  2.750000e+02  3.660000e+02
# Elapsed              6.446304e+08  1.004314e+09  1.296691e+09  1.521158e+09

# %%
data_raw.tail().T
# Out:
# Date                 2018-03-16  2018-03-16  2018-03-16  2018-03-16  \
# Ticker                     GOOG        MSFT          FB         IBM
# Adj Open                1.01621     1.00085    0.996758    0.998752
# Adj High                1.01774     1.00825      1.0013     1.01073
# Adj Low                0.996681    0.992812    0.990923    0.996131
# Adj Close -5d            1.0214     1.02051     1.00076    0.994072
# Adj Close -4d           1.02533     1.02294    0.998217           1
# Adj Close -3d           1.00215    0.997992    0.982657    0.994135
# Adj Close -2d           1.01212    0.992072    0.995138    0.986647
# Adj Close -1d           1.01219     0.99556    0.993355    0.995944
# Adj Close SMA6           1.0122     1.00484     0.99502    0.995133
# Adj Close SMA12        0.988174    0.996741    0.983215    0.984016
# Adj Close SMA20         0.98511    0.992014    0.978462    0.978828
# Adj Close SMA200       0.887937    0.843124    0.931621    0.933623
# Adj Close EMA3          1.00552    0.998716    0.996336    0.996504
# Adj Close EMA6          1.00406    0.999351    0.993114    0.993057
# Adj Close EMA12        0.995762    0.996417    0.987574    0.987178
# Adj Close EMA26        0.984571    0.985095    0.982755    0.981644
# Adj Close EMA50        0.972275    0.964799     0.97978    0.977278
# Adj Close BBandHi20     1.03251      1.0213     1.01381     1.00663
# Adj Close BBandLo20    0.937708    0.962731    0.943118    0.951023
# Volume -5d             0.819628    0.759102    0.788652     0.56624
# Volume -4d             0.836691    0.532637    0.651362    0.598594
# Volume -3d             0.734584    0.727258    0.769121    0.495496
# Volume -2d             0.459731    0.660348    0.700678    0.429936
# Volume -1d             0.537457    0.543182     0.66469     0.45701
# Days Since Trading            1           1           1           1
# Days Until Trading            1           1           1           1
# Year                       2018        2018        2018        2018
# Month                         3           3           3           3
# Week                         11          11          11          11
# Day                          16          16          16          16
# Dayofweek                     4           4           4           4
# Dayofyear                    75          75          75          75
# Is_month_end              False       False       False       False
# Is_month_start            False       False       False       False
# Is_quarter_end            False       False       False       False
# Is_quarter_start          False       False       False       False
# Is_year_end               False       False       False       False
# Is_year_start             False       False       False       False
# Elapsed              1521158400  1521158400  1521158400  1521158400
# Gain +1d                  False       False       False       False
#
# Date                 2018-03-16
# Ticker                     AAPL
# Adj Open                1.00354
# Adj High                1.00618
# Adj Low                0.997753
# Adj Close -5d           1.01101
# Adj Close -4d           1.02078
# Adj Close -3d           1.01095
# Adj Close -2d           1.00236
# Adj Close -1d           1.00354
# Adj Close SMA6          1.00811
# Adj Close SMA12        0.998694
# Adj Close SMA20        0.992102
# Adj Close SMA200       0.907903
# Adj Close EMA3          1.00254
# Adj Close EMA6          1.00299
# Adj Close EMA12        0.997918
# Adj Close EMA26         0.98395
# Adj Close EMA50        0.971619
# Adj Close BBandHi20     1.02507
# Adj Close BBandLo20    0.959133
# Volume -5d             0.849732
# Volume -4d              0.85031
# Volume -3d              0.83675
# Volume -2d             0.775364
# Volume -1d             0.598074
# Days Since Trading            1
# Days Until Trading            1
# Year                       2018
# Month                         3
# Week                         11
# Day                          16
# Dayofweek                     4
# Dayofyear                    75
# Is_month_end              False
# Is_month_start            False
# Is_quarter_end            False
# Is_quarter_start          False
# Is_year_end               False
# Is_year_start             False
# Elapsed              1521158400
# Gain +1d                  False

# %%
data_raw = data_raw.dropna()
data_raw.head().T
# Out:
# Date                1970-10-14 1970-10-15 1970-10-16 1970-10-19 1970-10-20
# Ticker                     IBM        IBM        IBM        IBM        IBM
# Adj Open               1.00172   0.994881    1.00774    1.00791   0.977243
# Adj High               1.01115     1.0064    1.00946    1.00791    1.00301
# Adj Low               0.995712   0.994881    0.99742   0.994728   0.977243
# Adj Close -5d          1.04889    1.01792    1.01849    1.02021    1.00301
# Adj Close -4d          1.02316    1.01067   0.998281    1.02636    1.00129
# Adj Close -3d          1.01587   0.990615     1.0043     1.0246    1.00644
# Adj Close -2d         0.995712   0.996587    1.00258    1.02988   0.998712
# Adj Close -1d          1.00171   0.994881    1.00774    1.02197   0.977244
# Adj Close SMA6         1.01422    1.00178    1.00523     1.0205   0.997782
# Adj Close SMA12        1.01987      1.015    1.02257    1.04137    1.01535
# Adj Close SMA20       0.998456   0.996161    1.00567    1.02935      1.009
# Adj Close SMA200       1.00813     1.0018    1.00827      1.029    1.00431
# Adj Close EMA3         1.00306   0.998964    1.00335    1.01269   0.994825
# Adj Close EMA6         1.00951     1.0031    1.00776    1.02135   0.998652
# Adj Close EMA12        1.00797    1.00238    1.00858    1.02601    1.00225
# Adj Close EMA26       0.983743   0.980285   0.988769    1.00971   0.987719
# Adj Close EMA50        0.95303   0.950185   0.959204    0.98105   0.960344
# Adj Close BBandHi20    1.06718    1.06043    1.06771     1.0879    1.05682
# Adj Close BBandLo20   0.929736   0.931888   0.943643   0.970802   0.961172
# Volume -5d             1.97727     1.8327    1.23514   0.799163    1.08125
# Volume -4d             2.19091    1.81749    0.98708   0.723849     0.6875
# Volume -3d             2.17273    1.45247   0.894057   0.460251   0.821875
# Volume -2d             1.73636    1.31559   0.568475   0.550209    1.20938
# Volume -1d             1.57273   0.836502   0.679587   0.809623    1.49375
# Days Since Trading           1          1          1          3          1
# Days Until Trading           1          1          3          1          1
# Year                      1970       1970       1970       1970       1970
# Month                       10         10         10         10         10
# Week                        42         42         42         43         43
# Day                         14         15         16         19         20
# Dayofweek                    2          3          4          0          1
# Dayofyear                  287        288        289        292        293
# Adj Close -4d        9.761354e-01  9.974534e-01  1.018342e+00  2.264551e+00
# Adj Close -3d        9.799794e-01  9.980365e-01  1.015883e+00  2.397760e+00
# Adj Close -2d        9.841103e-01  9.989295e-01  1.013215e+00  2.206186e+00
# Adj Close -1d        9.894212e-01  1.000000e+00  1.009344e+00  2.077671e+00
# Adj Close SMA6       9.854205e-01  9.983208e-01  1.010961e+00  1.846683e+00
# Adj Close SMA12      9.761041e-01  9.959932e-01  1.015922e+00  2.129611e+00
# Adj Close SMA20      9.663605e-01  9.928376e-01  1.020330e+00  2.321114e+00
# Adj Close SMA200     8.531209e-01  9.295127e-01  1.024804e+00  3.270508e+00
# Adj Close EMA3       9.934779e-01  9.993559e-01  1.005030e+00  1.513866e+00
# Adj Close EMA6       9.876372e-01  9.982471e-01  1.008813e+00  1.759399e+00
# Adj Close EMA12      9.791875e-01  9.959668e-01  1.013002e+00  1.952628e+00
# Adj Close EMA26      9.642503e-01  9.909578e-01  1.018299e+00  2.193185e+00
# Adj Close EMA50      9.442699e-01  9.824073e-01  1.022039e+00  2.296287e+00
# Adj Close BBandHi20  1.017509e+00  1.039730e+00  1.079198e+00  3.813682e+00
# Adj Close BBandLo20  9.008914e-01  9.456798e-01  9.736397e-01  1.538808e+00
# Volume -5d           7.365949e-01  1.013501e+00  1.373379e+00  1.590400e+06
# Volume -4d           7.449126e-01  1.014946e+00  1.362128e+00  2.911200e+06
# Volume -3d           7.511978e-01  1.013678e+00  1.352944e+00  3.924800e+06
# Volume -2d           7.657238e-01  1.017648e+00  1.330923e+00  2.710000e+06
# Volume -1d           7.987287e-01  1.015729e+00  1.273380e+00  3.030400e+06
# Days Since Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Days Until Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Year                 1.990000e+03  2.001000e+03  2.011000e+03  2.018000e+03
# Month                4.000000e+00  7.000000e+00  1.000000e+01  1.200000e+01
# Week                 1.400000e+01  2.700000e+01  4.000000e+01  5.300000e+01
# Day                  8.000000e+00  1.600000e+01  2.300000e+01  3.100000e+01
# Dayofweek            1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
# Dayofyear            9.200000e+01  1.830000e+02  2.750000e+02  3.660000e+02
# Elapsed              6.589728e+08  1.008288e+09  1.298354e+09  1.521158e+09

# %%
del data_raw['Elapsed']
del data_raw['Year']

# %%
train_cats(data_raw)
data_raw.head().T
# Out:
# Date                1970-10-14 1970-10-15 1970-10-16 1970-10-19 1970-10-20
# Ticker                     IBM        IBM        IBM        IBM        IBM
# Adj Open               1.00172   0.994881    1.00774    1.00791   0.977243
# Adj High               1.01115     1.0064    1.00946    1.00791    1.00301
# Adj Low               0.995712   0.994881    0.99742   0.994728   0.977243
# Adj Close -5d          1.04889    1.01792    1.01849    1.02021    1.00301
# Adj Close -4d          1.02316    1.01067   0.998281    1.02636    1.00129
# Adj Close -3d          1.01587   0.990615     1.0043     1.0246    1.00644
# Adj Close -2d         0.995712   0.996587    1.00258    1.02988   0.998712
# Adj Close -1d          1.00171   0.994881    1.00774    1.02197   0.977244
# Adj Close SMA6         1.01422    1.00178    1.00523     1.0205   0.997782
# Adj Close SMA12        1.01987      1.015    1.02257    1.04137    1.01535
# Adj Close SMA20       0.998456   0.996161    1.00567    1.02935      1.009
# Adj Close SMA200       1.00813     1.0018    1.00827      1.029    1.00431
# Adj Close EMA3         1.00306   0.998964    1.00335    1.01269   0.994825
# Adj Close EMA6         1.00951     1.0031    1.00776    1.02135   0.998652
# Adj Close EMA12        1.00797    1.00238    1.00858    1.02601    1.00225
# Adj Close EMA26       0.983743   0.980285   0.988769    1.00971   0.987719
# Adj Close EMA50        0.95303   0.950185   0.959204    0.98105   0.960344
# Adj Close BBandHi20    1.06718    1.06043    1.06771     1.0879    1.05682
# Adj Close BBandLo20   0.929736   0.931888   0.943643   0.970802   0.961172
# Volume -5d             1.97727     1.8327    1.23514   0.799163    1.08125
# Volume -4d             2.19091    1.81749    0.98708   0.723849     0.6875
# Volume -3d             2.17273    1.45247   0.894057   0.460251   0.821875
# Volume -2d             1.73636    1.31559   0.568475   0.550209    1.20938
# Volume -1d             1.57273   0.836502   0.679587   0.809623    1.49375
# Days Since Trading           1          1          1          3          1
# Days Until Trading           1          1          3          1          1
# Month                       10         10         10         10         10
# Week                        42         42         42         43         43
# Day                         14         15         16         19         20
# Dayofweek                    2          3          4          0          1
# Dayofyear                  287        288        289        292        293
# Is_month_end             False      False      False      False      False
# Is_month_start           False      False      False      False      False
# Is_quarter_end           False      False      False      False      False
# Is_quarter_start         False      False      False      False      False
# Is_year_end              False      False      False      False      False
# Is_year_start            False      False      False      False      False
# Gain +1d                  True      False      False       True      False

# %% [markdown]
# But let's save this file for now, since it's already in format can we be stored and accessed efficiently.

# %%
file_name = f'data/tmp/{STAMP}-gain-raw'

# %%
os.makedirs('data/tmp', exist_ok=True)
data_raw = data_raw.reset_index()
data_raw.to_feather(file_name)

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# In the future we can simply read it from this fast format.

# %%
df_raw = pd.read_feather(file_name)

# %%
df_raw = df_raw.set_index('Date')
df_raw.index
# Out:
# DatetimeIndex(['1970-10-14', '1970-10-15', '1970-10-16', '1970-10-19',
#                '1970-10-20', '1970-10-21', '1970-10-22', '1970-10-23',
#                '1970-10-26', '1970-10-27',
#                ...
#                '2018-03-15', '2018-03-15', '2018-03-15', '2018-03-15',
#                '2018-03-15', '2018-03-16', '2018-03-16', '2018-03-16',
#                '2018-03-16', '2018-03-16'],
#               dtype='datetime64[ns]', name='Date', length=33516, freq=None)

# %% [markdown]
# We'll replace categories with their numeric codes, handle missing continuous values, and split the dependent variable into a separate variable.

# %%
dep_col = 'Gain +1d'

# %%
df, y, nas = proc_df(df_raw, dep_col)

# %%
train_end = '2016-02'
valid_start = '2016-03'
valid_end = '2017-02'
test_start = '2017-03'

# %%
df_train = df[:train_end]
df_valid = df[valid_start : valid_end]
df_test = df[test_start:]
print(f'train, valid, test sizes: {len(df_train)}, {len(df_valid)}, {len(df_test)}')
# Out:
# train, valid, test sizes: 30936, 1260, 1320

# %%
X_train = df_train
X_valid = df_valid
X_test = df_test
print(f'train, valid, test sizes: {len(X_train)}, {len(X_valid)}, {len(X_test)}')
# Out:
# train, valid, test sizes: 30936, 1260, 1320

# %%
y, train_end
# Out:
# (array([ True, False, False, ..., False, False, False]), '2016-02')

# %%
y_train = y[:len(X_train)]
y_valid = y[len(X_train)+1 : -len(X_test)+1]
y_test = y[-len(X_test):]
print(f'train, valid, test sizes: {len(y_train)}, {len(y_valid)}, {len(y_test)}')
# Out:
# train, valid, test sizes: 30936, 1260, 1320

# %% [markdown]
# # Random Forests

# %% [markdown]
# ## Base model

# %% [markdown]
# Let's try our model again, this time with separate training and validation sets.

# %%
def rmse(x,y): return math.sqrt(((x-y)**2).mean())

def print_score(m):
    res = [m.score(X_train, y_train), m.score(X_valid, y_valid)]
    if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
m = RandomForestClassifier(n_estimators=100, min_samples_leaf=20, max_features='log2', n_jobs=-1, oob_score=True, random_state=42)
m.fit(X_train, y_train)
print_score(m)
# Out:
# [0.9111714507370055, 0.5063492063492063, 0.5257951900698216]

# %%
y_pred = m.predict(X_valid)
cnf_matrix = metrics.confusion_matrix(y_valid, y_pred)
cnf_matrix
# Out:
# array([[320, 256],
#        [366, 318]], dtype=int64)

# %%
def plot_metrics(metrics): return metrics.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)

# %%
def get_metrics(stamp, y_valid, y_pred, chance) :
    col = ['accuracy', 'precision','recall','f1','chance']
    val = []
    val.append(metrics.accuracy_score(y_valid, y_pred))
    val.append(metrics.precision_score(y_valid, y_pred))
    val.append(metrics.recall_score(y_valid, y_pred))
    val.append(metrics.f1_score(y_valid, y_pred))
    val.append(chance)
    
    return pd.DataFrame(data=[val], columns=col, index=[stamp])

# %%
# Percent of true gains over all samples: compare to precision -- precision should be signficantly higher if this is a useful
# prediction
# (cnf_matrix[1,0] + cnf_matrix[1,1]) / cnf_matrix.sum() 
chance = cnf_matrix[1:].sum() / cnf_matrix.sum()

# %%
met = get_metrics(STAMP, y_valid, y_pred, chance)

# %%
met.T.plot(kind='barh', figsize=(5,3), xlim=(0,1))
met
# Out:
#                accuracy  precision    recall        f1    chance
# 20180319-0916  0.506349   0.554007  0.464912  0.505564  0.542857

# %%
fi = rf_feat_importance(m, df)

# %%
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,8), legend=False)

# %%
plot_fi(fi)

# %% [markdown]
# ### Confidence

# %%
# %time preds = np.stack([t.predict(X_valid) for t in m.estimators_])
np.mean(preds[:,0]), np.std(preds[:,0])
# Out:
# Wall time: 1.47 s
# (0.41, 0.49183330509431744)

# %%
x = df_valid.copy()
x['pred_std'] = np.std(preds, axis=0)
x['pred'] = np.mean(preds, axis=0)

# %%
x['Gain +1d'] = y_valid

# %%
conf_gain = x.loc[x['pred'] >= 0.7]
conf_gain = pd.DataFrame(conf_gain, columns=['Ticker','pred','pred_std', 'Gain +1d'])
print(f"{len(conf_gain)} {len(conf_gain.loc[conf_gain['Gain +1d'] == True])/len(conf_gain)}")
# Out:
# 14 0.6428571428571429

# %%
conf_gain
# Out:
#             Ticker  pred  pred_std  Gain +1d
# Date
# 2016-03-31       4  0.72  0.448999      True
# 2016-04-01       2  0.74  0.438634     False
# 2016-04-01       1  0.72  0.448999     False
# 2016-04-04       1  0.70  0.458258     False
# 2016-04-28       3  0.74  0.438634      True
# 2016-05-03       5  0.72  0.448999     False
# 2016-05-06       2  0.70  0.458258      True
# 2016-07-15       4  0.74  0.438634      True
# 2016-08-05       5  0.73  0.443959     False
# 2016-08-05       3  0.74  0.438634      True
# 2016-11-14       2  0.73  0.443959      True
# 2016-12-02       4  0.71  0.453762      True
# 2016-12-15       4  0.70  0.458258      True
# 2017-02-28       4  0.70  0.458258      True
