# %% [markdown]
# # Nb-20180315-1603-RandomForest-GainPrediction

# %%
STAMP = "20180315-1603"

# %% [markdown]
# This is a modification of the notebook Nb-20180314-2218.
#
# Do a simple random forest to try to predict if a stock ticker will make a gain the next day.

# %% [markdown]
# Take basic structure of last notebook to create RandomForest for Gain Prediction, but:
# - create larger training/validation/test sets that are composed of multiple tickers.
# - keep date info to make it easier to analyze results

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from collections import defaultdict
import operator

# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.colors as colors
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics

# %%
import finance as fat

# %%
# Change the plot size.
plt.rcParams['figure.figsize'] = [18.0, 10.0]

# %%
tickers = ['AAPL', 'FB', 'IBM', 'GOOG', 'MSFT']

# %%
def create_ml_ticker_features_df(ticker) :
    data = fat.get_price_data(ticker)
    
    # check for required columns in data
    for c in ['Open','High','Low','Close','Adj Close', 'Volume'] :
        assert c in data.columns, f'{ticker} does not contain data for {c}'
    
    # Price features
    data = adjust_ohlc_prices(data)
    data = add_history(data, 'Adj Close', range(-5, 0))
    data = fat.add_sma_columns(data, 'Adj Close', [6,12,20,200])
    data = fat.add_ema_columns(data, 'Adj Close', [3,6,12,26,50])
    data = fat.add_bollinger_bands(data, 'Adj Close')
    data = scale_columns(data, 1.0/data['Adj Close'], column_contains='Adj')
    # 'Adj Close' data has all been scaled to 1.0, so get rid of it
    del data['Adj Close']
    # data = add_ohlc_booleans(data)
    
    # Volume features
    # ... first, replace 0's with 1's so we don't divide by zero when scaling (some data has 0's in volume)
    data['Volume'] = data['Volume'].replace(0, 1)
    data = add_history(data, 'Volume', range(-5, 0))
    data = scale_columns(data, 1.0/data['Volume'], column_contains='Volume')
    # 'Volume' data has all been scaled to 1.0, so get rid of it
    del data['Volume']
    
    return data

# %%
def adjust_ohlc_prices(data_frame, inplace=False) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    
    df = fat.use_data_frame_if_inplace(data_frame, inplace)
    
    columns = ['Open', 'High', 'Low', 'Close']
    scaling = df['Close'] / df['Adj Close']
    for c in columns :
        df[c] /= scaling
    
    del df['Adj Close']
    
    # rename columns, add 'Adj ' to name
    new_cols = {c : ('Adj '+c) for c in columns}
    df.rename(columns=new_cols, inplace=True)
    return df

# %%
def add_history(data_frame, column, day_range, inplace=False) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    df = fat.use_data_frame_if_inplace(data_frame, inplace)
    
    for i in day_range :
        df[f'{column} {i}d'] = df[column].shift(-i)
    return df

# %%
def scale_columns(data_frame, scaling, column_contains, inplace=False) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    df = fat.use_data_frame_if_inplace(data_frame, inplace)
    
    for c in df.columns : 
        if column_contains in c :
            df[c] *= scaling
    return df

# %%
def add_ticker(data_frame, ticker) :
    assert isinstance(data_frame, pd.DataFrame), \
        "data_frame must be pandas.DataFrame object"
    df = data_frame.copy()
    
    df['Ticker'] = ticker
    
    # ... and rearrange columns to put ticker in front 
    cols = df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    df = df[cols]
    
    return df

# %%
data_raw = None
for t in tickers :
    df = create_ml_ticker_features_df(t)
    df = fat.create_ml_features_df(df)
    df = add_ticker(df, t)
    
    data_raw = df.append(data_raw)
# Out:
# Loaded data for AAPL: 1980-12-12 to 2018-03-15.
# Loaded data for FB: 2012-05-18 to 2018-03-14.
# Loaded data for IBM: 1970-01-02 to 2018-03-15.
# Loaded data for GOOG: 2004-08-19 to 2018-03-14.
# Loaded data for MSFT: 1986-03-13 to 2018-03-15.

# %%
data_raw = data_raw.sort_index()
data_raw.describe().T
# Out:
#                        count          mean           std           min  \
# Adj Open             34504.0  1.000350e+00  3.750964e-02  8.384615e-01
# Adj High             34504.0  1.012602e+00  3.558592e-02  1.000000e+00
# Adj Low              34504.0  9.877496e-01  1.306489e-02  7.788786e-01
# Adj Close -5d        34479.0  9.975316e-01  5.094529e-02  5.995718e-01
# Adj Close -4d        34484.0  9.980311e-01  4.559672e-02  6.573880e-01
# Adj Close -3d        34489.0  9.985403e-01  3.981918e-02  6.766591e-01
# Adj Close -2d        34494.0  9.990367e-01  3.258646e-02  6.766591e-01
# Adj Close -1d        34499.0  9.995162e-01  2.292924e-02  7.505934e-01
# Adj Close SMA6       34479.0  9.987709e-01  2.819683e-02  7.519628e-01
# Adj Close SMA12      34449.0  9.972836e-01  4.297890e-02  6.572091e-01
# Adj Close SMA20      34409.0  9.953202e-01  5.781800e-02  6.183081e-01
# Adj Close SMA200     33509.0  9.525969e-01  1.879094e-01  4.509626e-01
# Adj Close EMA3       34504.0  9.995140e-01  1.322488e-02  8.678894e-01
# Adj Close EMA6       34504.0  9.987786e-01  2.338462e-02  7.912028e-01
# Adj Close EMA12      34504.0  9.973206e-01  3.669054e-02  7.054814e-01
# Adj Close EMA26      34504.0  9.939963e-01  5.749630e-02  6.283491e-01
# Adj Close EMA50      34504.0  9.884205e-01  8.197101e-02  5.941261e-01
# Adj Close BBandHi20  34409.0  1.062899e+00  9.080092e-02  8.551915e-01
# Adj Close BBandLo20  34409.0  9.277413e-01  6.703097e-02  7.583831e-02
# Volume -5d           34479.0  1.007527e+02  1.113710e+04  1.634949e-07
# Volume -4d           34484.0  1.876129e+02  2.111761e+04  2.906301e-07
# Volume -3d           34489.0  1.912897e+02  2.358417e+04  2.687016e-07
# Volume -2d           34494.0  1.472914e+02  1.708166e+04  2.021182e-07
# Volume -1d           34499.0  1.413061e+02  1.772368e+04  1.373551e-07
# Days Since Trading   34504.0  1.448731e+00  8.749163e-01  1.000000e+00
# Days Until Trading   34504.0  1.448731e+00  8.749163e-01  1.000000e+00
# Year                 34504.0  1.999580e+03  1.255730e+01  1.970000e+03
# Month                34504.0  6.531851e+00  3.441147e+00  1.000000e+00
# Week                 34504.0  2.659408e+01  1.502180e+01  1.000000e+00
# Day                  34504.0  1.573258e+01  8.745609e+00  1.000000e+00
# Dayofweek            34504.0  2.018230e+00  1.400307e+00  0.000000e+00
# Dayofyear            34504.0  1.833981e+02  1.051224e+02  2.000000e+00
# Elapsed              34504.0  9.492270e+08  3.962801e+08  8.640000e+04
#
#                               25%           50%           75%           max
# Adj Open             9.913860e-01  1.000000e+00  1.008769e+00  7.057778e+00
# Adj High             1.003832e+00  1.008427e+00  1.016397e+00  7.111111e+00
# Adj Low              9.836207e-01  9.915821e-01  9.962800e-01  1.000000e+00
# Adj Close -5d        9.727004e-01  9.965227e-01  1.020525e+00  2.424929e+00
# Adj Close -4d        9.758040e-01  9.974936e-01  1.018659e+00  2.264551e+00
# Adj Close -3d        9.797765e-01  9.980694e-01  1.016241e+00  2.397760e+00
# Adj Close -2d        9.839433e-01  9.989447e-01  1.013434e+00  2.206186e+00
# Adj Close -1d        9.893369e-01  1.000000e+00  1.009463e+00  2.077671e+00
# Adj Close SMA6       9.852476e-01  9.983689e-01  1.011193e+00  1.846683e+00
# Adj Close SMA12      9.758973e-01  9.960537e-01  1.016233e+00  2.129611e+00
# Adj Close SMA20      9.660000e-01  9.928601e-01  1.020782e+00  2.321114e+00
# Adj Close SMA200     8.531190e-01  9.295130e-01  1.024825e+00  3.270508e+00
# Adj Close EMA3       9.934081e-01  9.993749e-01  1.005138e+00  1.513866e+00
# Adj Close EMA6       9.875172e-01  9.982894e-01  1.009018e+00  1.759399e+00
# Adj Close EMA12      9.790486e-01  9.960315e-01  1.013337e+00  1.952628e+00
# Adj Close EMA26      9.639582e-01  9.910715e-01  1.018819e+00  2.193185e+00
# Adj Close EMA50      9.439840e-01  9.827302e-01  1.022953e+00  2.296287e+00
# Adj Close BBandHi20  1.017735e+00  1.040454e+00  1.080865e+00  3.813682e+00
# Adj Close BBandLo20  8.994179e-01  9.450685e-01  9.734210e-01  1.538808e+00
# Volume -5d           7.345745e-01  1.013616e+00  1.379239e+00  1.590400e+06
# Volume -4d           7.421872e-01  1.015397e+00  1.367127e+00  2.911200e+06
# Volume -3d           7.488135e-01  1.014599e+00  1.358325e+00  3.924800e+06
# Volume -2d           7.637654e-01  1.017484e+00  1.335702e+00  2.710000e+06
# Volume -1d           7.973484e-01  1.015795e+00  1.275795e+00  3.030400e+06
# Days Since Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Days Until Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Year                 1.990000e+03  2.001000e+03  2.011000e+03  2.018000e+03
# Month                4.000000e+00  7.000000e+00  1.000000e+01  1.200000e+01
# Week                 1.400000e+01  2.700000e+01  4.000000e+01  5.300000e+01
# Day                  8.000000e+00  1.600000e+01  2.300000e+01  3.100000e+01
# Dayofweek            1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
# Dayofyear            9.200000e+01  1.830000e+02  2.750000e+02  3.660000e+02
# Elapsed              6.445440e+08  1.004011e+09  1.296605e+09  1.521072e+09

# %%
data_raw['Gain +1d'] = data_raw['Adj Close -1d'].shift(-1) < 1.0
data_raw.tail().T
# Out:
# Date                 2018-03-14  2018-03-14  2018-03-15  2018-03-15  \
# Ticker                     AAPL         IBM        MSFT         IBM
# Adj Open                1.01054     1.01296    0.993098    0.994361
# Adj High                1.01166     1.01619     1.00425     1.01028
# Adj Low                0.996469    0.997597    0.985666    0.993171
# Adj Close -5d           0.98089     1.00126     1.00265    0.978698
# Adj Close -4d          0.991594    0.987921     1.02506     0.99812
# Adj Close -3d           1.00863     1.00753      1.0275     1.00407
# Adj Close -2d           1.01838     1.01353     1.00244    0.998183
# Adj Close -1d           1.00857     1.00759    0.996496    0.990665
# Adj Close SMA6          1.00134     1.00297     1.00903    0.994956
# Adj Close SMA12        0.996269    0.993386     1.00045     0.98571
# Adj Close SMA20        0.985197    0.989198    0.995408    0.981483
# Adj Close SMA200        0.90426    0.945481    0.845514    0.937043
# Adj Close EMA3          1.00426     1.00347     1.00188    0.997052
# Adj Close EMA6          1.00209     1.00139     1.00355    0.994313
# Adj Close EMA12        0.994103    0.996131     1.00021    0.988857
# Adj Close EMA26        0.978687    0.992163     0.98829    0.984167
# Adj Close EMA50        0.966829    0.988754    0.967658    0.980327
# Adj Close BBandHi20     1.02526     1.01455     1.02508     1.00762
# Adj Close BBandLo20    0.945131    0.963848    0.965736     0.95535
# Volume -5d              1.04023     1.26871    0.979456     1.67222
# Volume -4d             0.809513     1.77752     1.39751     1.23901
# Volume -3d              1.09591     1.31703    0.980587      1.3098
# Volume -2d              1.09666     1.39228     1.33888     1.08421
# Volume -1d              1.07917     1.15249      1.2157    0.940759
# Days Since Trading            1           1           1           1
# Days Until Trading            1           1           1           1
# Year                       2018        2018        2018        2018
# Month                         3           3           3           3
# Week                         11          11          11          11
# Day                          14          14          15          15
# Dayofweek                     2           2           3           3
# Dayofyear                    73          73          74          74
# Is_month_end              False       False       False       False
# Is_month_start            False       False       False       False
# Is_quarter_end            False       False       False       False
# Is_quarter_start          False       False       False       False
# Is_year_end               False       False       False       False
# Is_year_start             False       False       False       False
# Elapsed              1520985600  1520985600  1521072000  1521072000
# Gain +1d                  False        True        True        True
#
# Date                 2018-03-15
# Ticker                     AAPL
# Adj Open                0.99916
# Adj High                 1.0089
# Adj Low                0.996754
# Adj Close -5d          0.990428
# Adj Close -4d           1.00744
# Adj Close -3d           1.01718
# Adj Close -2d           1.00739
# Adj Close -1d          0.998825
# Adj Close SMA6          1.00355
# Adj Close SMA12        0.995219
# Adj Close SMA20        0.987196
# Adj Close SMA200       0.903946
# Adj Close EMA3          1.00154
# Adj Close EMA6          1.00065
# Adj Close EMA12        0.994022
# Adj Close EMA26        0.979201
# Adj Close EMA50        0.967038
# Adj Close BBandHi20     1.02103
# Adj Close BBandLo20    0.953364
# Volume -5d              1.04948
# Volume -4d              1.42078
# Volume -3d              1.42175
# Volume -2d              1.39907
# Volume -1d              1.29643
# Days Since Trading            1
# Days Until Trading            1
# Year                       2018
# Month                         3
# Week                         11
# Day                          15
# Dayofweek                     3
# Dayofyear                    74
# Is_month_end              False
# Is_month_start            False
# Is_quarter_end            False
# Is_quarter_start          False
# Is_year_end               False
# Is_year_start             False
# Elapsed              1521072000
# Gain +1d                  False

# %%
data_raw = data_raw.dropna()
data_raw.head().T
# Out:
# Date                1970-10-14 1970-10-15 1970-10-16 1970-10-19 1970-10-20
# Ticker                     IBM        IBM        IBM        IBM        IBM
# Adj Open               1.00172   0.994881    1.00774    1.00791   0.977243
# Adj High               1.01115     1.0064    1.00946    1.00791    1.00301
# Adj Low               0.995712   0.994881    0.99742   0.994728   0.977243
# Adj Close -5d          1.04889    1.01792    1.01849    1.02021    1.00301
# Adj Close -4d          1.02316    1.01067   0.998281    1.02636    1.00129
# Adj Close -3d          1.01587   0.990615     1.0043     1.0246    1.00644
# Adj Close -2d         0.995712   0.996587    1.00258    1.02988   0.998712
# Adj Close -1d          1.00171   0.994881    1.00774    1.02197   0.977244
# Adj Close SMA6         1.01422    1.00178    1.00523     1.0205   0.997782
# Adj Close SMA12        1.01987      1.015    1.02257    1.04137    1.01535
# Adj Close SMA20       0.998456   0.996161    1.00567    1.02935      1.009
# Adj Close SMA200       1.00813     1.0018    1.00827      1.029    1.00431
# Adj Close EMA3         1.00306   0.998964    1.00335    1.01269   0.994825
# Adj Close EMA6         1.00951     1.0031    1.00776    1.02135   0.998652
# Adj Close EMA12        1.00797    1.00238    1.00858    1.02601    1.00225
# Adj Close EMA26       0.983743   0.980285   0.988769    1.00971   0.987719
# Adj Close EMA50        0.95303   0.950185   0.959204    0.98105   0.960344
# Adj Close BBandHi20    1.06718    1.06043    1.06771     1.0879    1.05682
# Adj Close BBandLo20   0.929736   0.931888   0.943643   0.970802   0.961172
# Volume -5d             1.97727     1.8327    1.23514   0.799163    1.08125
# Volume -4d             2.19091    1.81749    0.98708   0.723849     0.6875
# Volume -3d             2.17273    1.45247   0.894057   0.460251   0.821875
# Volume -2d             1.73636    1.31559   0.568475   0.550209    1.20938
# Volume -1d             1.57273   0.836502   0.679587   0.809623    1.49375
# Days Since Trading           1          1          1          3          1
# Days Until Trading           1          1          3          1          1
# Year                      1970       1970       1970       1970       1970
# Month                       10         10         10         10         10
# Week                        42         42         42         43         43
# Day                         14         15         16         19         20
# Dayofweek                    2          3          4          0          1
# Dayofyear                  287        288        289        292        293
# Is_month_end             False      False      False      False      False
# Is_month_start           False      False      False      False      False
# Is_quarter_end           False      False      False      False      False
# Is_quarter_start         False      False      False      False      False
# Is_year_end              False      False      False      False      False
# Is_year_start            False      False      False      False      False
# Elapsed               24710400   24796800   24883200   25142400   25228800
# Gain +1d                  True      False      False       True      False

# %%
data_raw.describe().T
# Out:
#                        count          mean           std           min  \
# Adj Open             33509.0  1.000335e+00  3.789387e-02  8.384615e-01
# Adj High             33509.0  1.012556e+00  3.602009e-02  1.000000e+00
# Adj Low              33509.0  9.877485e-01  1.299984e-02  7.788786e-01
# Adj Close -5d        33509.0  9.974608e-01  5.011476e-02  5.995718e-01
# Adj Close -4d        33509.0  9.979741e-01  4.488178e-02  6.573880e-01
# Adj Close -3d        33509.0  9.984958e-01  3.925134e-02  6.766591e-01
# Adj Close -2d        33509.0  9.990027e-01  3.215511e-02  6.766591e-01
# Adj Close -1d        33509.0  9.995006e-01  2.270892e-02  7.505934e-01
# Adj Close SMA6       33509.0  9.987390e-01  2.776498e-02  7.519628e-01
# Adj Close SMA12      33509.0  9.972237e-01  4.239446e-02  6.572091e-01
# Adj Close SMA20      33509.0  9.952463e-01  5.708918e-02  6.183081e-01
# Adj Close SMA200     33509.0  9.525969e-01  1.879094e-01  4.509626e-01
# Adj Close EMA3       33509.0  9.994981e-01  1.304977e-02  8.678894e-01
# Adj Close EMA6       33509.0  9.987413e-01  2.304900e-02  7.912028e-01
# Adj Close EMA12      33509.0  9.972458e-01  3.617257e-02  7.054814e-01
# Adj Close EMA26      33509.0  9.938227e-01  5.670975e-02  6.283491e-01
# Adj Close EMA50      33509.0  9.880439e-01  8.100700e-02  5.941261e-01
# Adj Close BBandHi20  33509.0  1.061808e+00  9.006778e-02  8.551915e-01
# Adj Close BBandLo20  33509.0  9.286843e-01  6.613425e-02  7.583831e-02
# Volume -5d           33509.0  1.036280e+02  1.129714e+04  1.634949e-07
# Volume -4d           33509.0  1.930311e+02  2.142262e+04  2.906301e-07
# Volume -3d           33509.0  1.968450e+02  2.392654e+04  2.687016e-07
# Volume -2d           33509.0  1.515830e+02  1.733089e+04  2.021182e-07
# Volume -1d           33509.0  1.454455e+02  1.798358e+04  1.373551e-07
# Days Since Trading   33509.0  1.448685e+00  8.748372e-01  1.000000e+00
# Days Until Trading   33509.0  1.448685e+00  8.748372e-01  1.000000e+00
# Year                 33509.0  1.999843e+03  1.236308e+01  1.970000e+03
# Month                33509.0  6.536154e+00  3.444531e+00  1.000000e+00
# Week                 33509.0  2.660703e+01  1.503611e+01  1.000000e+00
# Day                  33509.0  1.573192e+01  8.745764e+00  1.000000e+00
# Dayofweek            33509.0  2.018323e+00  1.400225e+00  0.000000e+00
# Dayofyear            33509.0  1.835272e+02  1.052220e+02  2.000000e+00
# Elapsed              33509.0  9.575248e+08  3.900864e+08  2.471040e+07
#
#                               25%           50%           75%           max
# Adj Open             9.913799e-01  1.000000e+00  1.008727e+00  7.057778e+00
# Adj High             1.003775e+00  1.008403e+00  1.016334e+00  7.111111e+00
# Adj Low              9.836846e-01  9.915617e-01  9.962124e-01  1.000000e+00
# Adj Close -5d        9.729237e-01  9.964479e-01  1.020057e+00  2.424929e+00
# Adj Close -4d        9.761334e-01  9.974448e-01  1.018334e+00  2.264551e+00
# Adj Close -3d        9.799777e-01  9.980363e-01  1.015897e+00  2.397760e+00
# Adj Close -2d        9.841002e-01  9.989322e-01  1.013217e+00  2.206186e+00
# Adj Close -1d        9.894200e-01  1.000000e+00  1.009344e+00  2.077671e+00
# Adj Close SMA6       9.854196e-01  9.983187e-01  1.010964e+00  1.846683e+00
# Adj Close SMA12      9.760984e-01  9.959949e-01  1.015925e+00  2.129611e+00
# Adj Close SMA20      9.663458e-01  9.928452e-01  1.020335e+00  2.321114e+00
# Adj Close SMA200     8.531190e-01  9.295130e-01  1.024825e+00  3.270508e+00
# Adj Close EMA3       9.934766e-01  9.993576e-01  1.005033e+00  1.513866e+00
# Adj Close EMA6       9.876300e-01  9.982490e-01  1.008817e+00  1.759399e+00
# Adj Close EMA12      9.791843e-01  9.959696e-01  1.013005e+00  1.952628e+00
# Adj Close EMA26      9.642420e-01  9.909679e-01  1.018304e+00  2.193185e+00
# Adj Close EMA50      9.442555e-01  9.824150e-01  1.022047e+00  2.296287e+00
# Adj Close BBandHi20  1.017510e+00  1.039747e+00  1.079212e+00  3.813682e+00
# Adj Close BBandLo20  9.008712e-01  9.456769e-01  9.736478e-01  1.538808e+00
# Volume -5d           7.365741e-01  1.013561e+00  1.373507e+00  1.590400e+06
# Volume -4d           7.449416e-01  1.015061e+00  1.362147e+00  2.911200e+06
# Volume -3d           7.512411e-01  1.013793e+00  1.352973e+00  3.924800e+06
# Volume -2d           7.658576e-01  1.017677e+00  1.330950e+00  2.710000e+06
# Volume -1d           7.988377e-01  1.015795e+00  1.273455e+00  3.030400e+06
# Days Since Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Days Until Trading   1.000000e+00  1.000000e+00  1.000000e+00  7.000000e+00
# Year                 1.990000e+03  2.001000e+03  2.011000e+03  2.018000e+03
# Month                4.000000e+00  7.000000e+00  1.000000e+01  1.200000e+01
# Week                 1.400000e+01  2.700000e+01  4.000000e+01  5.300000e+01
# Day                  8.000000e+00  1.600000e+01  2.300000e+01  3.100000e+01
# Dayofweek            1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
# Dayofyear            9.200000e+01  1.830000e+02  2.750000e+02  3.660000e+02
# Elapsed              6.587136e+08  1.008202e+09  1.297987e+09  1.521072e+09

# %%
del data_raw['Elapsed']
del data_raw['Year']

# %%
train_cats(data_raw)
data_raw.head().T
# Out:
# Date                1970-10-14 1970-10-15 1970-10-16 1970-10-19 1970-10-20
# Ticker                     IBM        IBM        IBM        IBM        IBM
# Adj Open               1.00172   0.994881    1.00774    1.00791   0.977243
# Adj High               1.01115     1.0064    1.00946    1.00791    1.00301
# Adj Low               0.995712   0.994881    0.99742   0.994728   0.977243
# Adj Close -5d          1.04889    1.01792    1.01849    1.02021    1.00301
# Adj Close -4d          1.02316    1.01067   0.998281    1.02636    1.00129
# Adj Close -3d          1.01587   0.990615     1.0043     1.0246    1.00644
# Adj Close -2d         0.995712   0.996587    1.00258    1.02988   0.998712
# Adj Close -1d          1.00171   0.994881    1.00774    1.02197   0.977244
# Adj Close SMA6         1.01422    1.00178    1.00523     1.0205   0.997782
# Adj Close SMA12        1.01987      1.015    1.02257    1.04137    1.01535
# Adj Close SMA20       0.998456   0.996161    1.00567    1.02935      1.009
# Adj Close SMA200       1.00813     1.0018    1.00827      1.029    1.00431
# Adj Close EMA3         1.00306   0.998964    1.00335    1.01269   0.994825
# Adj Close EMA6         1.00951     1.0031    1.00776    1.02135   0.998652
# Adj Close EMA12        1.00797    1.00238    1.00858    1.02601    1.00225
# Adj Close EMA26       0.983743   0.980285   0.988769    1.00971   0.987719
# Adj Close EMA50        0.95303   0.950185   0.959204    0.98105   0.960344
# Adj Close BBandHi20    1.06718    1.06043    1.06771     1.0879    1.05682
# Adj Close BBandLo20   0.929736   0.931888   0.943643   0.970802   0.961172
# Volume -5d             1.97727     1.8327    1.23514   0.799163    1.08125
# Volume -4d             2.19091    1.81749    0.98708   0.723849     0.6875
# Volume -3d             2.17273    1.45247   0.894057   0.460251   0.821875
# Volume -2d             1.73636    1.31559   0.568475   0.550209    1.20938
# Volume -1d             1.57273   0.836502   0.679587   0.809623    1.49375
# Days Since Trading           1          1          1          3          1
# Days Until Trading           1          1          3          1          1
# Month                       10         10         10         10         10
# Week                        42         42         42         43         43
# Day                         14         15         16         19         20
# Dayofweek                    2          3          4          0          1
# Dayofyear                  287        288        289        292        293
# Is_month_end             False      False      False      False      False
# Is_month_start           False      False      False      False      False
# Is_quarter_end           False      False      False      False      False
# Is_quarter_start         False      False      False      False      False
# Is_year_end              False      False      False      False      False
# Is_year_start            False      False      False      False      False
# Gain +1d                  True      False      False       True      False

# %% [markdown]
# But let's save this file for now, since it's already in format can we be stored and accessed efficiently.

# %%
file_name = f'data/tmp/{STAMP}-gain-raw'

# %%
data_raw.index
# Out:
# DatetimeIndex(['1970-10-14', '1970-10-15', '1970-10-16', '1970-10-19',
#                '1970-10-20', '1970-10-21', '1970-10-22', '1970-10-23',
#                '1970-10-26', '1970-10-27',
#                ...
#                '2018-03-13', '2018-03-13', '2018-03-14', '2018-03-14',
#                '2018-03-14', '2018-03-14', '2018-03-14', '2018-03-15',
#                '2018-03-15', '2018-03-15'],
#               dtype='datetime64[ns]', name='Date', length=33509, freq=None)

# %%
os.makedirs('data/tmp', exist_ok=True)
data_raw = data_raw.reset_index()
data_raw.to_feather(file_name)

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# In the future we can simply read it from this fast format.

# %%
df_raw = pd.read_feather(file_name)

# %%
df_raw = df_raw.set_index('Date')
df_raw.index
# Out:
# DatetimeIndex(['1970-10-14', '1970-10-15', '1970-10-16', '1970-10-19',
#                '1970-10-20', '1970-10-21', '1970-10-22', '1970-10-23',
#                '1970-10-26', '1970-10-27',
#                ...
#                '2018-03-13', '2018-03-13', '2018-03-14', '2018-03-14',
#                '2018-03-14', '2018-03-14', '2018-03-14', '2018-03-15',
#                '2018-03-15', '2018-03-15'],
#               dtype='datetime64[ns]', name='Date', length=33509, freq=None)

# %% [markdown]
# We'll replace categories with their numeric codes, handle missing continuous values, and split the dependent variable into a separate variable.

# %%
dep_col = 'Gain +1d'

# %%
df, y, nas = proc_df(df_raw, dep_col)

# %%
train_end = '2016-02'
valid_start = '2016-03'
valid_end = '2017-02'
test_start = '2017-03'

# %%
df_train = df[:train_end]
df_valid = df[valid_start : valid_end]
df_test = df[test_start:]
print(f'train, valid, test sizes: {len(df_train)}, {len(df_valid)}, {len(df_test)}')
# Out:
# train, valid, test sizes: 30936, 1260, 1313

# %%
X_train = df_train
X_valid = df_valid
X_test = df_test
print(f'train, valid, test sizes: {len(X_train)}, {len(X_valid)}, {len(X_test)}')
# Out:
# train, valid, test sizes: 30936, 1260, 1313

# %%
y, train_end
# Out:
# (array([ True, False, False, ...,  True,  True, False]), '2016-02')

# %%
y_train = y[:len(X_train)]
y_valid = y[len(X_train)+1 : -len(X_test)+1]
y_test = y[-len(X_test):]
print(f'train, valid, test sizes: {len(y_train)}, {len(y_valid)}, {len(y_test)}')
# Out:
# train, valid, test sizes: 30936, 1260, 1313

# %% [markdown]
# # Random Forests

# %% [markdown]
# ## Base model

# %% [markdown]
# Let's try our model again, this time with separate training and validation sets.

# %%
def rmse(x,y): return math.sqrt(((x-y)**2).mean())

def print_score(m):
    res = [m.score(X_train, y_train), m.score(X_valid, y_valid)]
    if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %% [markdown]
# ## Bagging

# %%
m = RandomForestClassifier(n_estimators=100, min_samples_leaf=30, max_features='log2', n_jobs=-1, oob_score=True, random_state=42)
m.fit(X_train, y_train)
print_score(m)
# Out:
# [0.7107253685027153, 0.5888888888888889, 0.5887315748642359]

# %%
y_pred = m.predict(X_valid)
cnf_matrix = metrics.confusion_matrix(y_valid, y_pred)
cnf_matrix
# Out:
# array([[277, 297],
#        [221, 465]], dtype=int64)

# %%
def plot_metrics(metrics): return metrics.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)

# %%
def get_metrics(stamp, y_valid, y_pred, chance) :
    col = ['accuracy', 'precision','recall','f1','chance']
    val = []
    val.append(metrics.accuracy_score(y_valid, y_pred))
    val.append(metrics.precision_score(y_valid, y_pred))
    val.append(metrics.recall_score(y_valid, y_pred))
    val.append(metrics.f1_score(y_valid, y_pred))
    val.append(chance)
    
    return pd.DataFrame(data=[val], columns=col, index=[stamp])

# %%
# Percent of true gains over all samples: compare to precision -- precision should be signficantly higher if this is a useful
# prediction
# (cnf_matrix[1,0] + cnf_matrix[1,1]) / cnf_matrix.sum() 
chance = cnf_matrix[1:].sum() / cnf_matrix.sum()

# %%
met = get_metrics(STAMP, y_valid, y_pred, chance)

# %%
met.T.plot(kind='barh', figsize=(5,3), xlim=(0,1))
met
# Out:
#                accuracy  precision    recall        f1    chance
# 20180315-1603  0.588889   0.610236  0.677843  0.642265  0.544444

# %%
fi = rf_feat_importance(m, df)

# %%
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,8), legend=False)

# %%
plot_fi(fi)

# %% [markdown]
# ### Confidence

# %%
# %time preds = np.stack([t.predict(X_valid) for t in m.estimators_])
np.mean(preds[:,0]), np.std(preds[:,0])
# Out:
# Wall time: 1.07 s
# (0.79, 0.40730823708832603)

# %%
x = df_valid.copy()
x['pred_std'] = np.std(preds, axis=0)
x['pred'] = np.mean(preds, axis=0)

# %%
x['Gain +1d'] = y_valid

# %%
hi_conf_gain = x.loc[(x['pred'] - x['pred_std']) > 0.5]
len(hi_conf_gain)
# Out:
# 4

# %%
hi_conf_gain
# Out:
#             Ticker  Adj Open  Adj High   Adj Low  Adj Close -5d  \
# Date
# 2016-03-29       1  0.974090  1.001022  0.973997       0.983562
# 2016-07-08       5  0.989101  1.001147  0.985660       0.978394
# 2016-11-07       3  0.989751  1.003412  0.987259       1.002581
# 2016-11-21       2  0.970682  1.001478  0.967398       0.945060
#
#             Adj Close -4d  Adj Close -3d  Adj Close -2d  Adj Close -1d  \
# Date
# 2016-03-29       0.991085       0.985606       0.981334       0.976876
# 2016-07-08       0.978203       0.978394       0.982409       0.982409
# 2016-11-07       1.001393       0.982339       0.973943       0.973803
# 2016-11-21       0.962470       0.955408       0.967315       0.960992
#
#             Adj Close SMA6    ...     Is_month_end  Is_month_start  \
# Date                          ...
# 2016-03-29        0.986410    ...            False           False
# 2016-07-08        0.983301    ...            False           False
# 2016-11-07        0.989010    ...            False           False
# 2016-11-21        0.965208    ...            False           False
#
#             Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start  \
# Date
# 2016-03-29           False             False        False          False
# 2016-07-08           False             False        False          False
# 2016-11-07           False             False        False          False
# 2016-11-21           False             False        False          False
#
#             pred_std  pred  Gain +1d    Return
# Date
# 2016-03-29  0.346987  0.86     False  1.007734
# 2016-07-08  0.324962  0.88      True  1.014769
# 2016-11-07  0.312890  0.89      True  1.011594
# 2016-11-21  0.286182  0.91      True  0.998791
#
# [4 rows x 42 columns]

# %%
hi_conf_no_gain = x.loc[(x['pred'] + x['pred_std']) < 0.5]
hi_conf_no_gain
# Out:
#             Ticker  Adj Open  Adj High   Adj Low  Adj Close -5d  \
# Date
# 2016-04-04       2  1.013505  1.017770  0.991648       1.010129
# 2016-04-07       1  1.012991  1.017321  0.996130       1.004146
# 2016-04-22       3  1.010476  1.024138  0.992821       1.055971
# 2016-06-10       2  1.007889  1.012777  0.996913       1.015863
# 2016-06-17       2  1.012387  1.012476  0.995930       1.031853
# 2016-06-17       1  1.013532  1.013847  0.999685       1.036714
# 2016-06-27       4  1.018676  1.021603  0.993031       1.070453
# 2016-06-27       2  1.023860  1.023860  0.993209       1.040378
# 2016-07-25       1  1.009349  1.015410  0.995685       1.025580
# 2016-09-08       1  1.016395  1.016585  0.997346       1.005496
# 2016-09-09       1  1.014642  1.025114  1.000000       1.034908
# 2016-09-09       3  1.013743  1.017883  1.000000       1.012005
# 2016-09-29       3  1.008297  1.013922  0.998996       1.015742
# 2016-10-11       5  1.012240  1.014513  0.994754       1.000874
# 2016-12-12       2  1.012312  1.012482  0.998981       0.997113
#
#             Adj Close -4d  Adj Close -3d  Adj Close -2d  Adj Close -1d  \
# Date
# 2016-04-04       1.031897       1.019103       1.013772       1.031186
# 2016-04-07       1.013359       1.023770       1.011701       1.022296
# 2016-04-22       1.066558       1.048917       1.047164       1.056165
# 2016-06-10       1.018607       1.009775       1.015177       1.016635
# 2016-06-17       1.008229       1.016988       1.013980       1.012122
# 2016-06-17       1.021085       1.022344       1.018987       1.023288
# 2016-06-27       1.073519       1.065645       1.082579       1.021533
# 2016-06-27       1.049647       1.045334       1.056070       1.028540
# 2016-07-25       1.025991       1.026916       1.021471       1.013561
# 2016-09-08       1.011467       1.020944       1.020659       1.026914
# 2016-09-09       1.044604       1.044313       1.050713       1.023175
# 2016-09-09       1.015533       1.026881       1.027236       1.020615
# 2016-09-29       1.015342       0.998968       1.010322       1.008451
# 2016-10-11       1.007868       1.009617       1.010666       1.014863
# 2016-12-12       0.996094       1.001528       1.009680       1.016218
#
#             Adj Close SMA6    ...     Dayofyear  Is_month_end  Is_month_start  \
# Date                          ...
# 2016-04-04        1.017681    ...            95         False           False
# 2016-04-07        1.012545    ...            98         False           False
# 2016-04-22        1.045796    ...           113         False           False
# 2016-06-10        1.012676    ...           162         False           False
# 2016-06-17        1.013862    ...           169         False           False
# 2016-06-17        1.020403    ...           169         False           False
# 2016-06-27        1.052288    ...           179         False           False
# 2016-06-27        1.036661    ...           179         False           False
# 2016-07-25        1.018920    ...           207         False           False
# 2016-09-08        1.014247    ...           252         False           False
# 2016-09-09        1.032952    ...           253         False           False
# 2016-09-09        1.017045    ...           253         False           False
# 2016-09-29        1.008138    ...           273         False           False
# 2016-10-11        1.007315    ...           285         False           False
# 2016-12-12        1.003439    ...           347         False           False
#
#             Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start  \
# Date
# 2016-04-04           False             False        False          False
# 2016-04-07           False             False        False          False
# 2016-04-22           False             False        False          False
# 2016-06-10           False             False        False          False
# 2016-06-17           False             False        False          False
# 2016-06-17           False             False        False          False
# 2016-06-27           False             False        False          False
# 2016-06-27           False             False        False          False
# 2016-07-25           False             False        False          False
# 2016-09-08           False             False        False          False
# 2016-09-09           False             False        False          False
# 2016-09-09           False             False        False          False
# 2016-09-29           False             False        False          False
# 2016-10-11           False             False        False          False
# 2016-12-12           False             False        False          False
#
#             pred_std  pred  Gain +1d
# Date
# 2016-04-04  0.324962  0.12     False
# 2016-04-07  0.271293  0.08      True
# 2016-04-22  0.336303  0.13     False
# 2016-06-10  0.346987  0.14     False
# 2016-06-17  0.346987  0.14     False
# 2016-06-17  0.324962  0.12     False
# 2016-06-27  0.312890  0.11     False
# 2016-06-27  0.324962  0.12     False
# 2016-07-25  0.336303  0.13      True
# 2016-09-08  0.312890  0.11     False
# 2016-09-09  0.324962  0.12     False
# 2016-09-09  0.324962  0.12      True
# 2016-09-29  0.286182  0.09     False
# 2016-10-11  0.346987  0.14     False
# 2016-12-12  0.324962  0.12      True
#
# [15 rows x 41 columns]

# %%
conf_gain = x.loc[x['pred'] > 0.75]
conf_gain = pd.DataFrame(conf_gain, columns=['Ticker','pred','pred_std', 'Gain +1d'])
len(conf_gain.loc[conf_gain['Gain +1d'] == True])/len(conf_gain)
# Out:
# 0.8032786885245902

# %%
conf_no_gain = x.loc[x['pred'] < 0.25]
conf_no_gain = pd.DataFrame(conf_no_gain, columns=['Ticker','pred','pred_std', 'Gain +1d'])
len(conf_no_gain.loc[conf_no_gain['Gain +1d'] == False])/len(conf_no_gain)
# Out:
# 0.7040816326530612

# %%
len(conf_gain)
# Out:
# 61

# %%
conf_gain
# Out:
#             Ticker  pred  pred_std  Gain +1d
# Date
# 2016-03-01       1  0.79  0.407308      True
# 2016-03-01       4  0.82  0.384187      True
# 2016-03-01       5  0.79  0.407308      True
# 2016-03-01       2  0.82  0.384187      True
# 2016-03-01       3  0.82  0.384187      True
# 2016-03-09       3  0.84  0.366606      True
# 2016-03-09       5  0.80  0.400000      True
# 2016-03-09       2  0.82  0.384187     False
# 2016-03-11       3  0.82  0.384187      True
# 2016-03-11       4  0.77  0.420833      True
# 2016-03-11       2  0.85  0.357071      True
# 2016-03-16       3  0.76  0.427083     False
# 2016-03-16       2  0.76  0.427083      True
# 2016-03-24       4  0.81  0.392301      True
# 2016-03-29       5  0.83  0.375633      True
# 2016-03-29       1  0.86  0.346987     False
# 2016-04-06       3  0.76  0.427083      True
# 2016-04-13       1  0.81  0.392301      True
# 2016-05-06       2  0.78  0.414246      True
# 2016-05-10       5  0.79  0.407308      True
# 2016-05-16       1  0.76  0.427083      True
# 2016-05-24       3  0.81  0.392301      True
# 2016-05-25       1  0.80  0.400000     False
# 2016-06-08       3  0.79  0.407308      True
# 2016-06-16       1  0.78  0.414246      True
# 2016-06-23       5  0.76  0.427083     False
# 2016-06-29       2  0.76  0.427083      True
# 2016-07-08       2  0.79  0.407308      True
# 2016-07-08       5  0.88  0.324962      True
# 2016-07-08       4  0.80  0.400000      True
# ...            ...   ...       ...       ...
# 2016-07-18       1  0.83  0.375633      True
# 2016-07-18       2  0.82  0.384187      True
# 2016-07-18       3  0.81  0.392301     False
# 2016-08-01       1  0.81  0.392301      True
# 2016-08-17       2  0.83  0.375633      True
# 2016-09-12       3  0.78  0.414246     False
# 2016-09-15       3  0.76  0.427083      True
# 2016-09-27       2  0.81  0.392301      True
# 2016-10-10       3  0.76  0.427083      True
# 2016-10-10       2  0.78  0.414246     False
# 2016-10-14       1  0.78  0.414246      True
# 2016-10-24       1  0.80  0.400000      True
# 2016-11-07       5  0.78  0.414246      True
# 2016-11-07       3  0.89  0.312890      True
# 2016-11-08       2  0.82  0.384187      True
# 2016-11-08       1  0.76  0.427083      True
# 2016-11-15       5  0.82  0.384187      True
# 2016-11-16       5  0.76  0.427083      True
# 2016-11-16       1  0.81  0.392301      True
# 2016-11-21       2  0.91  0.286182      True
# 2016-12-05       3  0.81  0.392301      True
# 2016-12-05       5  0.80  0.400000      True
# 2016-12-07       1  0.84  0.366606      True
# 2016-12-07       3  0.77  0.420833      True
# 2016-12-09       3  0.83  0.375633      True
# 2016-12-09       5  0.77  0.420833     False
# 2016-12-20       4  0.78  0.414246     False
# 2016-12-23       1  0.76  0.427083     False
# 2017-01-25       1  0.82  0.384187      True
# 2017-02-08       2  0.82  0.384187     False
#
# [61 rows x 4 columns]

# %%
nas
# Out:
# {}
