# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# Change the plot size.
plt.rcParams['figure.figsize'] = [18.0, 12.0]

# %%
import pandas as pd

# %%
# import my Finance Analysis Tools (fat)
import finance as fat

# %%
data = fat.get_price_data('IAU')
# Out:
# Loaded data for IAU: 2005-01-28 to 2018-02-16.

# %%
data.tail()
# Out:
#              Open   High    Low  Close  Adj Close      Volume
# Date
# 2018-02-12  12.66  12.74  12.66  12.68      12.68  11623200.0
# 2018-02-13  12.74  12.77  12.70  12.76      12.76   8174100.0
# 2018-02-14  12.80  13.02  12.78  12.98      12.98  19514800.0
# 2018-02-15  13.01  13.02  12.95  12.99      12.99  13914600.0
# 2018-02-16  12.98  13.03  12.92  12.95      12.95  13611800.0

# %%
fat.add_sma_info(data, 'Adj Close')

# %%
data.tail()
# Out:
#              Open   High    Low  Close  Adj Close      Volume  Adj Close SMA5  \
# Date
# 2018-02-12  12.66  12.74  12.66  12.68      12.68  11623200.0          12.654
# 2018-02-13  12.74  12.77  12.70  12.76      12.76   8174100.0          12.668
# 2018-02-14  12.80  13.02  12.78  12.98      12.98  19514800.0          12.740
# 2018-02-15  13.01  13.02  12.95  12.99      12.99  13914600.0          12.808
# 2018-02-16  12.98  13.03  12.92  12.95      12.95  13611800.0          12.872
#
#             Adj Close SMA10  Adj Close SMA20  Adj Close SMA50  \
# Date
# 2018-02-12           12.764          12.8165          12.5242
# 2018-02-13           12.757          12.8115          12.5344
# 2018-02-14           12.763          12.8220          12.5480
# 2018-02-15           12.765          12.8340          12.5624
# 2018-02-16           12.780          12.8425          12.5780
#
#             Adj Close SMA100  Adj Close SMA200
# Date
# 2018-02-12           12.4289          12.30300
# 2018-02-13           12.4315          12.30575
# 2018-02-14           12.4372          12.31020
# 2018-02-15           12.4424          12.31465
# 2018-02-16           12.4459          12.31980

# %%
search = "gold price usd"
trends, related_queries = fat.get_google_trends(data, search)

# %%
related_queries
# Out:
# {'gold price usd': {'rising':                   query    value
#   0           gold to usd  6236400
#   1     gold price in usd  3135100
#   2               usd inr  2625650
#   3            inr to usd  2243250
#   4     price of gold usd  1493500
#   5         price of gold  1450900
#   6            usd in inr  1290000
#   7              usd rate  1107600
#   8             gold rate  1083900
#   9      india gold price  1018900
#   10     gold price today   930900
#   11         1 usd to inr   780250
#   12  gold price in india   751700
#   13             currency   732600
#   14     gold ounce price   701650
#   15              gbp usd   678100
#   16              usd cad   655750
#   17              aud usd   596350
#   18     gold price chart   589600
#   19         dollar price   585450
#   20       gold price aud   581050
#   21           gold chart   575050
#   22              eur usd   568900
#   23  gold price per gram   539250
#   24           usd to cad   529050, 'top':                       query  value
#   0               gold to usd    100
#   1         gold price in usd     50
#   2                   usd inr     42
#   3                inr to usd     36
#   4         price of gold usd     24
#   5             price of gold     23
#   6                usd in inr     21
#   7                  usd rate     18
#   8                 gold rate     17
#   9          india gold price     16
#   10         gold price today     15
#   11             1 usd to inr     13
#   12      gold price in india     12
#   13                 currency     12
#   14         gold ounce price     11
#   15                  gbp usd     11
#   16                  usd cad     11
#   17                  aud usd     10
#   18         gold price chart      9
#   19             dollar price      9
#   20           gold price aud      9
#   21               gold chart      9
#   22                  eur usd      9
#   23  gold price per gram usd      9
#   24      gold price per gram      9}}

# %%
data[search] = trends[search]

# %%
data[-14:]
# Out:
#              Open   High    Low  Close  Adj Close      Volume  Adj Close SMA5  \
# Date
# 2018-01-30  12.94  12.95  12.83  12.83      12.83   9532200.0          12.934
# 2018-01-31  12.90  12.94  12.79  12.92      12.92  20848500.0          12.908
# 2018-02-01  12.88  12.97  12.86  12.97      12.97  13352000.0          12.914
# 2018-02-02  12.84  12.84  12.75  12.80      12.80  15380700.0          12.880
# 2018-02-05  12.84  12.89  12.80  12.85      12.85  18014000.0          12.874
# 2018-02-06  12.81  12.82  12.67  12.69      12.69  19535100.0          12.846
# 2018-02-07  12.69  12.73  12.59  12.62      12.62  11388300.0          12.786
# 2018-02-08  12.65  12.70  12.60  12.65      12.65  12123600.0          12.722
# 2018-02-09  12.62  12.67  12.59  12.63      12.63  11514000.0          12.688
# 2018-02-12  12.66  12.74  12.66  12.68      12.68  11623200.0          12.654
# 2018-02-13  12.74  12.77  12.70  12.76      12.76   8174100.0          12.668
# 2018-02-14  12.80  13.02  12.78  12.98      12.98  19514800.0          12.740
# 2018-02-15  13.01  13.02  12.95  12.99      12.99  13914600.0          12.808
# 2018-02-16  12.98  13.03  12.92  12.95      12.95  13611800.0          12.872
#
#             Adj Close SMA10  Adj Close SMA20  Adj Close SMA50  \
# Date
# 2018-01-30           12.866          12.7880          12.4544
# 2018-01-31           12.881          12.8005          12.4670
# 2018-02-01           12.903          12.8170          12.4778
# 2018-02-02           12.905          12.8215          12.4882
# 2018-02-05           12.909          12.8295          12.4992
# 2018-02-06           12.890          12.8295          12.5046
# 2018-02-07           12.847          12.8290          12.5094
# 2018-02-08           12.818          12.8285          12.5136
# 2018-02-09           12.784          12.8255          12.5176
# 2018-02-12           12.764          12.8165          12.5242
# 2018-02-13           12.757          12.8115          12.5344
# 2018-02-14           12.763          12.8220          12.5480
# 2018-02-15           12.765          12.8340          12.5624
# 2018-02-16           12.780          12.8425          12.5780
#
#             Adj Close SMA100  Adj Close SMA200  gold price usd
# Date
# 2018-01-30           12.4289          12.28205       81.677419
# 2018-01-31           12.4285          12.28490       81.838710
# 2018-02-01           12.4287          12.28770       82.000000
# 2018-02-02           12.4291          12.29015             NaN
# 2018-02-05           12.4296          12.29275             NaN
# 2018-02-06           12.4294          12.29435             NaN
# 2018-02-07           12.4280          12.29600             NaN
# 2018-02-08           12.4275          12.29845             NaN
# 2018-02-09           12.4281          12.30050             NaN
# 2018-02-12           12.4289          12.30300             NaN
# 2018-02-13           12.4315          12.30575             NaN
# 2018-02-14           12.4372          12.31020             NaN
# 2018-02-15           12.4424          12.31465             NaN
# 2018-02-16           12.4459          12.31980             NaN

# %%
plot_data = data[['Adj Close', search,'Adj Close SMA20','Adj Close SMA50','Adj Close SMA200']]
plot_data.plot(secondary_y = [search])

# %%
trends.plot()

# %%
trends.tail()
